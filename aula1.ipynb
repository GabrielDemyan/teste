# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielDemyan/teste/blob/main/aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.fft import fft, fftfreq
import matplotlib.pyplot as plt
import IPython.display
from IPython.display import Audio, display


frequencies_to_plot = [500, 5000, 10000]

sampling_frequency = 44100 # Hz
duration_plot = 0.01 # seconds
duration_au = 1

t = np.arange(0, duration_plot, 1/sampling_frequency, dtype=float)
t_au = np.arange(0, duration_au, 1/sampling_frequency, dtype=float)

for freq in frequencies_to_plot:
    # Generate a cosine signal for the current frequency
    signal_to_plot = 1 * np.cos(2 * np.pi * freq * t)

    plt.figure(figsize=(12, 4))
    plt.plot(t, signal_to_plot)
    plt.title(f'Sinal Senoidal no Domínio do Tempo ({freq} Hz)')
    plt.xlabel('Tempo (s)')
    plt.ylabel('Amplitude')
    plt.grid(True)
    plt.show()

    signal_au = 1 * np.cos(2 * np.pi * freq * t_au)
    print(f"Audio")
    display(Audio(signal_au, rate = sampling_frequency))
# Out:
# Audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import chirp
from IPython.display import Audio, display

sampling_frequency = 44100
duration  = 0.01
duration_au = 1
t_sig = np.arange(0,  duration, 1/sampling_frequency, dtype=np.float32)
t_au = np.arange(0,  duration_au, 1/sampling_frequency, dtype=np.float32)

signal_chirp = chirp(t_sig, f0=500, f1=10000, t1=duration, method='linear')

plt.figure(figsize=(12, 4))
plt.plot(t_sig, signal_chirp)
plt.title('Sinal')
plt.xlabel('Tempo')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 4))
plt.specgram(signal_chirp, Fs=sampling_frequency, cmap = "plasma")
plt.title('Espectograma')
plt.xlabel('Tempo')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

signal_au = chirp(t_au, f0=500, f1=10000, t1=duration_au, method='linear')
print('\n audio \n')
display(Audio(signal_au, rate=sampling_frequency))
# Out:
#  audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%

import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from IPython.display import Audio, display
import os

handel = "https://github.com/GabrielDemyan/teste/raw/refs/heads/main/Aula1/data_handel.wav"
nome_handel = "Aula1_data_handel.wav"

# !wget -O handel nome_handel

sampling_frequency, signal = wavfile.read(nome_handel)

if len(signal.shape) > 1:
  signal = signal[:, 0]

t = len(signal) / sampling_frequency
t_sig = np.arange(0,  duration, t, len(signal))

plt.figure(figsize=(12, 4))
plt.plot(t_sig, signal)
plt.title('Sinal')
plt.xlabel('Tempo')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()
# Out:
# --2026-08-17 19:24:50--  http://nome_handel/
# Resolving nome_handel (nome_handel)... failed: Name or service not known.
# wget: unable to resolve host address ‘nome_handel’
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_823/2777148232.py in <cell line: 0>()
#      12 get_ipython().system('wget -O handel nome_handel')
#      13
# ---> 14 sampling_frequency, signal = wavfile.read(nome_handel)
#      15
#      16 if len(signal.shape) > 1:
#
# /usr/local/lib/python3.12/dist-packages/scipy/io/wavfile.py in read(filename, mmap)
#     713         mmap = False
#     714     else:
# --> 715         fid = open(filename, 'rb')
#     716
#     717     if not (was_seekable := fid.seekable()):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Aula1_data_handel.wav'
